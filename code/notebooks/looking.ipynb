# %%
import matplotlib.pyplot as plt
import pickle as pkl

# %%
# path = '../../runs/toybox-tokh-120424/poincareplot_tokh.pkl'
# path = '../../runs/ncsx-37-convdom/convergence_domain_04150027.pkl'
path = '../../runs/toybox-tok-shear-150424/poincare_04151543.pkl'

# %%
fig = pkl.load(open(path, 'rb'))
ax = fig.get_axes()[0]
plt.show()

# %%
fig
