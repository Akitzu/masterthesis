# %%
import matplotlib.pyplot as plt
import pickle as pkl

# %%
# path = '../output/toybox_conv_hist0z1e-10_morepoints.pkl'
# path = '../../runs/toybox-tokh-120424/poincareplot_tokh.pkl'
# path = '../../runs/ncsx-37-convdom/convergence_domain_04150027.pkl'
# path = '../../runs/toybox-tok-shear-1504/unperturbed/poincare_04160931.pkl'
# path = '../../runs/toybox-tok-shear-1504/perturbed-3-2/manifold_04170029.pkl'
# path = '../../runs/toybox-tok-1404/poincare_04170914.pkl'

# path = '../../runs/toybox-tok-1404/trace/trace_M_04171926.pkl'
# path = '../../runs/toybox-tok-1704/perturbed-5-2/poincare_04171421.pkl'

# path = '../../runs/toybox-tok-1404/conv-unperturbed/convdom_04160312.pkl'
# path = '../../runs/toybox-tok-1404/conv-unperturbed-cart/convdom_04160519.pkl'

# path = '../../runs/toybox-tok-1504/unperturbed/poincare_04151535.pkl'
path =  '../../runs/toybox-tok-1404/ill_condition/ratio_M_04181347.pkl'
path =  '../../runs/toybox-tok-1704/perturbed-13-2/manifold_04181436.pkl'

# %%
fig = pkl.load(open(path, 'rb'))
ax = fig.get_axes()[0]

# %%
fig.set_size_inches(10, 10)

# %%
# ax.set_xlim(6,6.3)
# ax.set_ylim(-4.7,-4.4)

ax.set_xlim(3.8, 9)
ax.set_ylim(-6, 2.5)

# ax.set_xlim(3.10,3.115)
# ax.set_ylim(-1.665,-1.645)
# ax.legend(loc='upper right')

# ax.set_xlim(2.4, 4)
# ax.set_ylim(-2.2, 0.7)

plt.show()
fig
